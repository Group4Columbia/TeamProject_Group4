# %%
## Analyze the Relationship between HDI and Total CAses

# %%
import pandas as pd
from pathlib import Path
import matplotlib.pyplot as plt
from sklearn.linear_model import LinearRegression

# %%
covid_19_df = pd.read_csv('Project Resources/covid_map_data.csv')
covid_19_df.head(5)
# Out:
#   location iso_code        date  total_vaccinations_x  people_vaccinated_x  \
# 0  Albania      ALB  01/10/2021                   0.0                  0.0
# 1  Albania      ALB  01/11/2021                   NaN                  NaN
# 2  Albania      ALB  01/12/2021                 128.0                128.0
# 3  Albania      ALB  01/13/2021                 188.0                188.0
# 4  Albania      ALB  01/14/2021                 266.0                266.0
#
#    people_fully_vaccinated  daily_vaccinations_raw  daily_vaccinations  \
# 0                      NaN                     NaN                 NaN
# 1                      NaN                     NaN                64.0
# 2                      NaN                     NaN                64.0
# 3                      NaN                    60.0                63.0
# 4                      NaN                    78.0                66.0
#
#    total_vaccinations_per_hundred  people_vaccinated_per_hundred  ...  \
# 0                            0.00                           0.00  ...
# 1                             NaN                            NaN  ...
# 2                            0.00                           0.00  ...
# 3                            0.01                           0.01  ...
# 4                            0.01                           0.01  ...
#
#    total_cases  new_cases new_deaths population_density gdp_per_capita  \
# 0          NaN        NaN        NaN                NaN            NaN
# 1          NaN        NaN        NaN                NaN            NaN
# 2          NaN        NaN        NaN                NaN            NaN
# 3      65334.0      707.0        4.0            104.871      11803.431
# 4      65994.0      660.0        5.0            104.871      11803.431
#
#    handwashing_facilities  diabetes_prevalence  hospital_beds_per_thousand  \
# 0                     NaN                  NaN                         NaN
# 1                     NaN                  NaN                         NaN
# 2                     NaN                  NaN                         NaN
# 3                     0.0                10.08                        2.89
# 4                     0.0                10.08                        2.89
#
#    life_expectancy  human_development_index
# 0              NaN                      NaN
# 1              NaN                      NaN
# 2              NaN                      NaN
# 3            78.57                    0.795
# 4            78.57                    0.795
#
# [5 rows x 28 columns]

# %%
final_df = covid_19_df.drop(columns=["people_fully_vaccinated", "total_vaccinations_per_hundred", "people_vaccinated_per_hundred", "people_fully_vaccinated_per_hundred", "daily_vaccinations_per_million", "Note", "new_cases", "new_deaths", "handwashing_facilities", "hospital_beds_per_thousand", "Country", "Status", "diabetes_prevalence", "life_expectancy"])

# %%
covid_final_df = final_df.dropna()
covid_final_df.head()
# Out:
#   location iso_code        date  total_vaccinations_x  people_vaccinated_x  \
# 3  Albania      ALB  01/13/2021                 188.0                188.0
# 4  Albania      ALB  01/14/2021                 266.0                266.0
# 5  Albania      ALB  01/15/2021                 308.0                308.0
# 6  Albania      ALB  01/16/2021                 369.0                369.0
# 7  Albania      ALB  01/17/2021                 405.0                405.0
#
#    daily_vaccinations_raw  daily_vaccinations  total_vaccinations_y  \
# 3                    60.0                63.0                 188.0
# 4                    78.0                66.0                 266.0
# 5                    42.0                62.0                 308.0
# 6                    61.0                62.0                 369.0
# 7                    36.0                58.0                 405.0
#
#    people_vaccinated_y  total_deaths  total_cases  population_density  \
# 3                188.0        1256.0      65334.0             104.871
# 4                266.0        1261.0      65994.0             104.871
# 5                308.0        1265.0      66635.0             104.871
# 6                369.0        1270.0      67216.0             104.871
# 7                405.0        1277.0      67690.0             104.871
#
#    gdp_per_capita  human_development_index
# 3       11803.431                    0.795
# 4       11803.431                    0.795
# 5       11803.431                    0.795
# 6       11803.431                    0.795
# 7       11803.431                    0.795

# %%
covid_final_df["total_cases"] = covid_final_df["total_cases"].astype(int)
covid_final_df.dtypes
# Out:
# /opt/anaconda3/envs/mlenv/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# location                    object
# iso_code                    object
# date                        object
# total_vaccinations_x       float64
# people_vaccinated_x        float64
# daily_vaccinations_raw     float64
# daily_vaccinations         float64
# total_vaccinations_y       float64
# people_vaccinated_y        float64
# total_deaths               float64
# total_cases                  int64
# population_density         float64
# gdp_per_capita             float64
# human_development_index    float64
# dtype: object

# %%
covid_final_df = covid_final_df[covid_final_df.human_development_index >=.7]
covid_final_df.head()
# Out:
#   location iso_code        date  total_vaccinations_x  people_vaccinated_x  \
# 3  Albania      ALB  01/13/2021                 188.0                188.0
# 4  Albania      ALB  01/14/2021                 266.0                266.0
# 5  Albania      ALB  01/15/2021                 308.0                308.0
# 6  Albania      ALB  01/16/2021                 369.0                369.0
# 7  Albania      ALB  01/17/2021                 405.0                405.0
#
#    daily_vaccinations_raw  daily_vaccinations  total_vaccinations_y  \
# 3                    60.0                63.0                 188.0
# 4                    78.0                66.0                 266.0
# 5                    42.0                62.0                 308.0
# 6                    61.0                62.0                 369.0
# 7                    36.0                58.0                 405.0
#
#    people_vaccinated_y  total_deaths  total_cases  population_density  \
# 3                188.0        1256.0        65334             104.871
# 4                266.0        1261.0        65994             104.871
# 5                308.0        1265.0        66635             104.871
# 6                369.0        1270.0        67216             104.871
# 7                405.0        1277.0        67690             104.871
#
#    gdp_per_capita  human_development_index
# 3       11803.431                    0.795
# 4       11803.431                    0.795
# 5       11803.431                    0.795
# 6       11803.431                    0.795
# 7       11803.431                    0.795

# %%
covid_final_df = covid_final_df[covid_final_df.human_development_index <=.9]
covid_final_df.head()
# Out:
#   location iso_code        date  total_vaccinations_x  people_vaccinated_x  \
# 3  Albania      ALB  01/13/2021                 188.0                188.0
# 4  Albania      ALB  01/14/2021                 266.0                266.0
# 5  Albania      ALB  01/15/2021                 308.0                308.0
# 6  Albania      ALB  01/16/2021                 369.0                369.0
# 7  Albania      ALB  01/17/2021                 405.0                405.0
#
#    daily_vaccinations_raw  daily_vaccinations  total_vaccinations_y  \
# 3                    60.0                63.0                 188.0
# 4                    78.0                66.0                 266.0
# 5                    42.0                62.0                 308.0
# 6                    61.0                62.0                 369.0
# 7                    36.0                58.0                 405.0
#
#    people_vaccinated_y  total_deaths  total_cases  population_density  \
# 3                188.0        1256.0        65334             104.871
# 4                266.0        1261.0        65994             104.871
# 5                308.0        1265.0        66635             104.871
# 6                369.0        1270.0        67216             104.871
# 7                405.0        1277.0        67690             104.871
#
#    gdp_per_capita  human_development_index
# 3       11803.431                    0.795
# 4       11803.431                    0.795
# 5       11803.431                    0.795
# 6       11803.431                    0.795
# 7       11803.431                    0.795

# %%
### Relationship Betweeen HDI and Total Cases
plt.scatter(covid_final_df.human_development_index, covid_final_df.total_cases)
plt.xlabel("Human Development Index")
plt.ylabel("Global Total Cases")
plt.show()

# %%
X = covid_final_df.human_development_index.values.reshape(-1,1)

# %%
y = covid_final_df.total_cases

# %%
model = LinearRegression()

# %%
model.fit(X,y)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X)
print(y_pred.shape)
# Out:
# (720,)

# %%
### HDI Range of .7-.9
plt.scatter(X, y)
plt.plot(X, y_pred, color='green')
plt.xlabel("Human Development Index")
plt.ylabel("Global Total Cases")
plt.title("COVID-19 Total Cases by Human Development Index")
plt.show()

# %%
print(model.coef_)
print(model.intercept_)
# Out:
# [-15307961.86387488]
# 14033210.328094047

# %%
hdi_column = covid_final_df['human_development_index']
cases_column = covid_final_df['total_cases']

# %%
correlation = hdi_column.corr(cases_column)
correlation
# Out:
# -0.36788003829179483

# %% [markdown]
# # This negative relationship between countries with a HDI between .7 and .9 and total cases was to be expected. As a countries Human Development Index, or HDI, gets better, the less cases there are going to be. The correlation between the two variables is -36.79%. Countries with a greater HDI probably have more access to healthcare facilities and healthcare professionals, which in turn will slow down the spread of cases of COVID-19.
